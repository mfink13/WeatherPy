# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 808

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | padang
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | carutapera
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | yinchuan
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | chicama
# Processing Record 11 of Set 1 | taman
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | pionerskiy
# Processing Record 19 of Set 1 | college
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | toledo
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | talnakh
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | vestmanna
# Processing Record 26 of Set 1 | cilegon
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | kuusankoski
# Processing Record 30 of Set 1 | nosy varika
# Processing Record 31 of Set 1 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | powell river
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | leningradskiy
# Processing Record 37 of Set 1 | conceicao do araguaia
# Processing Record 38 of Set 1 | fukue
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | iwanai
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | turayf
# Processing Record 46 of Set 1 | paramonga
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | lompoc
# Processing Record 1 of Set 2 | jiroft
# City not found. Skipping...
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | madimba
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | harper
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | vao
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | port shepstone
# Processing Record 14 of Set 2 | sai buri
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | shenzhen
# Processing Record 17 of Set 2 | port blair
# Processing Record 18 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | sibolga
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | koundara
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | hornepayne
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | codrington
# Processing Record 30 of Set 2 | concepcion
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | synya
# Processing Record 33 of Set 2 | tajao
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | west wendover
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | bintulu
# Processing Record 39 of Set 2 | trairi
# Processing Record 40 of Set 2 | bandarbeyla
# Processing Record 41 of Set 2 | nome
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | biak
# Processing Record 44 of Set 2 | rognan
# Processing Record 45 of Set 2 | fairbanks
# Processing Record 46 of Set 2 | kamiiso
# Processing Record 47 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 2 | san quintin
# Processing Record 49 of Set 2 | matara
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | ayorou
# Processing Record 2 of Set 3 | jacareacanga
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 3 | bahile
# Processing Record 6 of Set 3 | port augusta
# Processing Record 7 of Set 3 | labuhan
# Processing Record 8 of Set 3 | ushuaia
# Processing Record 9 of Set 3 | kathmandu
# Processing Record 10 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 3 | merritt island
# Processing Record 12 of Set 3 | srednekolymsk
# Processing Record 13 of Set 3 | ola
# Processing Record 14 of Set 3 | boende
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | fort nelson
# Processing Record 17 of Set 3 | wajir
# Processing Record 18 of Set 3 | berlevag
# Processing Record 19 of Set 3 | paraiso
# Processing Record 20 of Set 3 | guane
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | monrovia
# Processing Record 24 of Set 3 | lata
# Processing Record 25 of Set 3 | ouesso
# Processing Record 26 of Set 3 | teya
# Processing Record 27 of Set 3 | khandyga
# Processing Record 28 of Set 3 | vila franca do campo
# Processing Record 29 of Set 3 | santa marinella
# Processing Record 30 of Set 3 | tommot
# Processing Record 31 of Set 3 | miri
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | russellville
# Processing Record 34 of Set 3 | vanimo
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | hilo
# Processing Record 37 of Set 3 | sterling
# Processing Record 38 of Set 3 | laguna
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | yerbogachen
# Processing Record 42 of Set 3 | muros
# Processing Record 43 of Set 3 | faya
# Processing Record 44 of Set 3 | pokhara
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | shubarkuduk
# Processing Record 47 of Set 3 | kenai
# Processing Record 48 of Set 3 | nanzhang
# Processing Record 49 of Set 3 | joshimath
# Processing Record 50 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 4 | wonji
# City not found. Skipping...
# Processing Record 2 of Set 4 | san bernardo
# Processing Record 3 of Set 4 | constitucion
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | kavieng
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | kurumkan
# Processing Record 9 of Set 4 | la cruz
# Processing Record 10 of Set 4 | velluru
# City not found. Skipping...
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | puerto narino
# Processing Record 13 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 4 | olafsvik
# Processing Record 15 of Set 4 | cockburn town
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | kuusamo
# Processing Record 18 of Set 4 | bambous virieux
# Processing Record 19 of Set 4 | palu
# Processing Record 20 of Set 4 | presidente medici
# Processing Record 21 of Set 4 | cervo
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | sabha
# Processing Record 25 of Set 4 | virginia beach
# Processing Record 26 of Set 4 | altamira
# Processing Record 27 of Set 4 | skibbereen
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | panama city
# Processing Record 31 of Set 4 | gamba
# Processing Record 32 of Set 4 | benjamin hill
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | nara
# Processing Record 35 of Set 4 | namtsy
# Processing Record 36 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 4 | kaoma
# Processing Record 39 of Set 4 | alice springs
# Processing Record 40 of Set 4 | pangody
# Processing Record 41 of Set 4 | mandurah
# Processing Record 42 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 4 | marang
# Processing Record 44 of Set 4 | izhma
# Processing Record 45 of Set 4 | daru
# Processing Record 46 of Set 4 | margate
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | mayo
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 2 of Set 5 | san pedro de ycuamandiyu
# Processing Record 3 of Set 5 | lagoa
# Processing Record 4 of Set 5 | santa cruz
# Processing Record 5 of Set 5 | tura
# Processing Record 6 of Set 5 | dobson
# Processing Record 7 of Set 5 | aripuana
# Processing Record 8 of Set 5 | mattru
# Processing Record 9 of Set 5 | takoradi
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | at-bashi
# Processing Record 12 of Set 5 | tuzha
# Processing Record 13 of Set 5 | gondanglegi
# Processing Record 14 of Set 5 | nelson bay
# Processing Record 15 of Set 5 | davila
# Processing Record 16 of Set 5 | hofn
# Processing Record 17 of Set 5 | sept-iles
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | bukama
# Processing Record 20 of Set 5 | saint-louis
# Processing Record 21 of Set 5 | henties bay
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | kastamonu
# Processing Record 24 of Set 5 | itaituba
# Processing Record 25 of Set 5 | plettenberg bay
# Processing Record 26 of Set 5 | haimen
# Processing Record 27 of Set 5 | centralia
# Processing Record 28 of Set 5 | ugoofaaru
# Processing Record 29 of Set 5 | thinadhoo
# Processing Record 30 of Set 5 | kaniama
# Processing Record 31 of Set 5 | opuwo
# Processing Record 32 of Set 5 | carnarvon
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | nehe
# Processing Record 35 of Set 5 | sangar
# Processing Record 36 of Set 5 | hunchun
# Processing Record 37 of Set 5 | santarem
# Processing Record 38 of Set 5 | fortuna
# Processing Record 39 of Set 5 | catemaco
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | kuvandyk
# Processing Record 42 of Set 5 | sikeston
# Processing Record 43 of Set 5 | luanda
# Processing Record 44 of Set 5 | riohacha
# Processing Record 45 of Set 5 | port moresby
# Processing Record 46 of Set 5 | loei
# Processing Record 47 of Set 5 | souris
# Processing Record 48 of Set 5 | san patricio
# Processing Record 49 of Set 5 | praia
# Processing Record 50 of Set 5 | pandan
# Processing Record 1 of Set 6 | monte escobedo
# Processing Record 2 of Set 6 | ribeira grande
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | zhigansk
# Processing Record 5 of Set 6 | quatre cocos
# Processing Record 6 of Set 6 | karpathos
# Processing Record 7 of Set 6 | egvekinot
# Processing Record 8 of Set 6 | alyangula
# Processing Record 9 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 6 | sorong
# Processing Record 11 of Set 6 | oriximina
# Processing Record 12 of Set 6 | odweyne
# Processing Record 13 of Set 6 | ulaanbaatar
# Processing Record 14 of Set 6 | sobolevo
# Processing Record 15 of Set 6 | cabo san lucas
# Processing Record 16 of Set 6 | sault sainte marie
# Processing Record 17 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 6 | mocuba
# Processing Record 19 of Set 6 | kunming
# Processing Record 20 of Set 6 | placido de castro
# Processing Record 21 of Set 6 | oistins
# Processing Record 22 of Set 6 | patti
# Processing Record 23 of Set 6 | lamu
# Processing Record 24 of Set 6 | kyabram
# Processing Record 25 of Set 6 | mula
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | thompson
# Processing Record 28 of Set 6 | peniche
# Processing Record 29 of Set 6 | rio grande
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 33 of Set 6 | mandalay
# Processing Record 34 of Set 6 | ouahigouya
# Processing Record 35 of Set 6 | petropavl
# Processing Record 36 of Set 6 | roros
# Processing Record 37 of Set 6 | ust-karsk
# Processing Record 38 of Set 6 | pandan niog
# Processing Record 39 of Set 6 | sabi
# Processing Record 40 of Set 6 | cauquenes
# Processing Record 41 of Set 6 | ulverstone
# Processing Record 42 of Set 6 | molokovo
# Processing Record 43 of Set 6 | gisborne
# Processing Record 44 of Set 6 | northam
# Processing Record 45 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 6 | byron bay
# Processing Record 47 of Set 6 | karratha
# Processing Record 48 of Set 6 | businga
# Processing Record 49 of Set 6 | maine-soroa
# Processing Record 50 of Set 6 | namibe
# Processing Record 1 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | piacabucu
# Processing Record 4 of Set 7 | kushiro
# Processing Record 5 of Set 7 | isangel
# Processing Record 6 of Set 7 | naze
# Processing Record 7 of Set 7 | roald
# Processing Record 8 of Set 7 | kizlyar
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | aden
# Processing Record 11 of Set 7 | iseyin
# Processing Record 12 of Set 7 | mumford
# Processing Record 13 of Set 7 | yartsevo
# Processing Record 14 of Set 7 | batalha
# Processing Record 15 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 | bubaque
# Processing Record 17 of Set 7 | knysna
# Processing Record 18 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | catuday
# Processing Record 20 of Set 7 | hirara
# Processing Record 21 of Set 7 | tadine
# Processing Record 22 of Set 7 | el reno
# Processing Record 23 of Set 7 | inongo
# Processing Record 24 of Set 7 | mount gambier
# Processing Record 25 of Set 7 | oranjemund
# Processing Record 26 of Set 7 | wajima
# Processing Record 27 of Set 7 | dossor
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | beringovskiy
# Processing Record 30 of Set 7 | balaipungut
# Processing Record 31 of Set 7 | aleksandrov gay
# Processing Record 32 of Set 7 | vardo
# Processing Record 33 of Set 7 | caxito
# Processing Record 34 of Set 7 | port arthur
# Processing Record 35 of Set 7 | yefremov
# Processing Record 36 of Set 7 | jha jha
# Processing Record 37 of Set 7 | chernyshevskiy
# Processing Record 38 of Set 7 | phuket
# Processing Record 39 of Set 7 | deputatskiy
# Processing Record 40 of Set 7 | kapaa
# Processing Record 41 of Set 7 | kayes
# Processing Record 42 of Set 7 | yumen
# Processing Record 43 of Set 7 | great yarmouth
# Processing Record 44 of Set 7 | caronport
# Processing Record 45 of Set 7 | dunedin
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | tabou
# Processing Record 48 of Set 7 | kwinana
# Processing Record 49 of Set 7 | clyde river
# Processing Record 50 of Set 7 | jalu
# Processing Record 1 of Set 8 | hualmay
# Processing Record 2 of Set 8 | ilulissat
# Processing Record 3 of Set 8 | cherskiy
# Processing Record 4 of Set 8 | sola
# Processing Record 5 of Set 8 | kimberley
# Processing Record 6 of Set 8 | sao francisco
# Processing Record 7 of Set 8 | ayan
# Processing Record 8 of Set 8 | yelbarga
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | grand gaube
# Processing Record 11 of Set 8 | camacha
# Processing Record 12 of Set 8 | sarkand
# Processing Record 13 of Set 8 | lixourion
# Processing Record 14 of Set 8 | waitati
# Processing Record 15 of Set 8 | kruisfontein
# Processing Record 16 of Set 8 | batagay-alyta
# Processing Record 17 of Set 8 | kaitangata
# Processing Record 18 of Set 8 | paamiut
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | saint-francois
# Processing Record 22 of Set 8 | pervomayskoye
# Processing Record 23 of Set 8 | saint-junien
# Processing Record 24 of Set 8 | makinsk
# Processing Record 25 of Set 8 | alto araguaia
# Processing Record 26 of Set 8 | rivadavia
# Processing Record 27 of Set 8 | hovd
# Processing Record 28 of Set 8 | lavrentiya
# Processing Record 29 of Set 8 | penzance
# Processing Record 30 of Set 8 | huarmey
# Processing Record 31 of Set 8 | butembo
# Processing Record 32 of Set 8 | nova friburgo
# Processing Record 33 of Set 8 | iqaluit
# Processing Record 34 of Set 8 | nassjo
# Processing Record 35 of Set 8 | bilma
# Processing Record 36 of Set 8 | north bend
# Processing Record 37 of Set 8 | flinders
# Processing Record 38 of Set 8 | portland
# Processing Record 39 of Set 8 | lieksa
# Processing Record 40 of Set 8 | passau
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | melo
# Processing Record 43 of Set 8 | srandakan
# Processing Record 44 of Set 8 | santa fe
# Processing Record 45 of Set 8 | phirangipuram
# Processing Record 46 of Set 8 | norman wells
# Processing Record 47 of Set 8 | abalak
# Processing Record 48 of Set 8 | westerland
# Processing Record 49 of Set 8 | shenjiamen
# Processing Record 50 of Set 8 | pedasi
# Processing Record 1 of Set 9 | lalmohan
# Processing Record 2 of Set 9 | koungou
# Processing Record 3 of Set 9 | tinskoy
# Processing Record 4 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 9 | kyrylivka
# Processing Record 6 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 9 | neftcala
# Processing Record 8 of Set 9 | buchanan
# Processing Record 9 of Set 9 | brae
# Processing Record 10 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 11 of Set 9 | fontem
# Processing Record 12 of Set 9 | maravilha
# Processing Record 13 of Set 9 | santa isabel do rio negro
# Processing Record 14 of Set 9 | kashi
# Processing Record 15 of Set 9 | aquiraz
# Processing Record 16 of Set 9 | curup
# Processing Record 17 of Set 9 | lasa
# Processing Record 18 of Set 9 | maun
# Processing Record 19 of Set 9 | miandrivazo
# Processing Record 20 of Set 9 | muli
# Processing Record 21 of Set 9 | canico
# Processing Record 22 of Set 9 | severo-kurilsk
# Processing Record 23 of Set 9 | chapais
# Processing Record 24 of Set 9 | cururupu
# Processing Record 25 of Set 9 | havre-saint-pierre
# Processing Record 26 of Set 9 | fatikchhari
# City not found. Skipping...
# Processing Record 27 of Set 9 | puerto madero
# Processing Record 28 of Set 9 | narodychi
# Processing Record 29 of Set 9 | semey
# Processing Record 30 of Set 9 | tuktoyaktuk
# Processing Record 31 of Set 9 | kirakira
# Processing Record 32 of Set 9 | muzhi
# Processing Record 33 of Set 9 | matamoros
# Processing Record 34 of Set 9 | russell
# Processing Record 35 of Set 9 | vaitape
# Processing Record 36 of Set 9 | bismarck
# Processing Record 37 of Set 9 | port-cartier
# Processing Record 38 of Set 9 | blackwater
# Processing Record 39 of Set 9 | guilin
# Processing Record 40 of Set 9 | poum
# Processing Record 41 of Set 9 | ixtapa
# Processing Record 42 of Set 9 | port hardy
# Processing Record 43 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 9 | kuytun
# Processing Record 45 of Set 9 | kampene
# Processing Record 46 of Set 9 | rosita
# Processing Record 47 of Set 9 | engenheiro beltrao
# Processing Record 48 of Set 9 | teknaf
# Processing Record 49 of Set 9 | floro
# Processing Record 50 of Set 9 | la sarre
# Processing Record 1 of Set 10 | buala
# Processing Record 2 of Set 10 | kysyl-syr
# Processing Record 3 of Set 10 | petrovskaya
# Processing Record 4 of Set 10 | launceston
# Processing Record 5 of Set 10 | turukhansk
# Processing Record 6 of Set 10 | kapchorwa
# Processing Record 7 of Set 10 | del rio
# Processing Record 8 of Set 10 | chernyshevsk
# Processing Record 9 of Set 10 | banda aceh
# Processing Record 10 of Set 10 | liberal
# Processing Record 11 of Set 10 | townsville
# Processing Record 12 of Set 10 | taiobeiras
# Processing Record 13 of Set 10 | quang ngai
# Processing Record 14 of Set 10 | aykhal
# Processing Record 15 of Set 10 | panorama
# Processing Record 16 of Set 10 | meulaboh
# Processing Record 17 of Set 10 | roebourne
# Processing Record 18 of Set 10 | ikongo
# Processing Record 19 of Set 10 | bathsheba
# Processing Record 20 of Set 10 | aksu
# Processing Record 21 of Set 10 | manokwari
# Processing Record 22 of Set 10 | krasnoselkup
# Processing Record 23 of Set 10 | kamenka
# Processing Record 24 of Set 10 | broome
# Processing Record 25 of Set 10 | pyapon
# Processing Record 26 of Set 10 | saint-philippe
# Processing Record 27 of Set 10 | shihezi
# Processing Record 28 of Set 10 | kitimat
# Processing Record 29 of Set 10 | porto tolle
# Processing Record 30 of Set 10 | tuy hoa
# Processing Record 31 of Set 10 | ankang
# Processing Record 32 of Set 10 | rawah
# Processing Record 33 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 10 | dungarpur
# Processing Record 35 of Set 10 | kongolo
# Processing Record 36 of Set 10 | green river
# Processing Record 37 of Set 10 | mahaut
# Processing Record 38 of Set 10 | kavant
# City not found. Skipping...
# Processing Record 39 of Set 10 | rawlins
# Processing Record 40 of Set 10 | la baule-escoublac
# Processing Record 41 of Set 10 | santa cruz del sur
# Processing Record 42 of Set 10 | ozinki
# Processing Record 43 of Set 10 | arkul
# Processing Record 44 of Set 10 | auki
# Processing Record 45 of Set 10 | ereymentau
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | ziarat
# Processing Record 48 of Set 10 | rehoboth
# Processing Record 49 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 10 | avera
# Processing Record 1 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 11 | pocao de pedras
# Processing Record 3 of Set 11 | lubaczow
# Processing Record 4 of Set 11 | tarakan
# Processing Record 5 of Set 11 | la orilla
# Processing Record 6 of Set 11 | bogotol
# Processing Record 7 of Set 11 | celestun
# Processing Record 8 of Set 11 | humberto de campos
# Processing Record 9 of Set 11 | turgenevo
# Processing Record 10 of Set 11 | boyolangu
# Processing Record 11 of Set 11 | dahegam
# Processing Record 12 of Set 11 | savannah bight
# Processing Record 13 of Set 11 | valdosta
# Processing Record 14 of Set 11 | surt
# Processing Record 15 of Set 11 | terrasini
# Processing Record 16 of Set 11 | qrendi
# Processing Record 17 of Set 11 | monaghan
# Processing Record 18 of Set 11 | borinskoye
# Processing Record 19 of Set 11 | ylivieska
# Processing Record 20 of Set 11 | porto walter
# Processing Record 21 of Set 11 | sotouboua
# Processing Record 22 of Set 11 | oussouye
# Processing Record 23 of Set 11 | ranfurly
# Processing Record 24 of Set 11 | ca mau
# Processing Record 25 of Set 11 | akyab
# Processing Record 26 of Set 11 | samarai
# Processing Record 27 of Set 11 | san vicente
# Processing Record 28 of Set 11 | provideniya
# Processing Record 29 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 11 | devonport
# Processing Record 31 of Set 11 | araceli
# Processing Record 32 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | olinda
# Processing Record 35 of Set 11 | spornoye
# Processing Record 36 of Set 11 | krasnoslobodsk
# Processing Record 37 of Set 11 | zhanaozen
# Processing Record 38 of Set 11 | adrar
# Processing Record 39 of Set 11 | tromso
# Processing Record 40 of Set 11 | saurimo
# Processing Record 41 of Set 11 | beloha
# Processing Record 42 of Set 11 | vangaindrano
# Processing Record 43 of Set 11 | vila
# Processing Record 44 of Set 11 | ambunti
# Processing Record 45 of Set 11 | nova serrana
# Processing Record 46 of Set 11 | rio bravo
# Processing Record 47 of Set 11 | yaan
# Processing Record 48 of Set 11 | villeneuve-sur-lot
# Processing Record 49 of Set 11 | cidreira
# Processing Record 50 of Set 11 | innisfail
# Processing Record 1 of Set 12 | kieta
# Processing Record 2 of Set 12 | pinotepa nacional
# Processing Record 3 of Set 12 | jurm
# Processing Record 4 of Set 12 | smithers
# Processing Record 5 of Set 12 | saint-leu
# Processing Record 6 of Set 12 | narasannapeta
# Processing Record 7 of Set 12 | san ramon
# Processing Record 8 of Set 12 | houma
# Processing Record 9 of Set 12 | falconara marittima
# Processing Record 10 of Set 12 | wenling
# Processing Record 11 of Set 12 | kloulklubed
# Processing Record 12 of Set 12 | klaksvik
# Processing Record 13 of Set 12 | talavera de la reina
# Processing Record 14 of Set 12 | bhag
# Processing Record 15 of Set 12 | awbari
# Processing Record 16 of Set 12 | gombong
# Processing Record 17 of Set 12 | castano primo
# Processing Record 18 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 19 of Set 12 | batemans bay
# Processing Record 20 of Set 12 | panjab
# Processing Record 21 of Set 12 | tamandare
# Processing Record 22 of Set 12 | soissons
# Processing Record 23 of Set 12 | grants pass
# Processing Record 24 of Set 12 | smolenka
# Processing Record 25 of Set 12 | mitu
# Processing Record 26 of Set 12 | canavieiras
# Processing Record 27 of Set 12 | bo phloi
# Processing Record 28 of Set 12 | urumqi
# Processing Record 29 of Set 12 | pisco
# Processing Record 30 of Set 12 | dorado
# Processing Record 31 of Set 12 | eureka
# Processing Record 32 of Set 12 | portree
# Processing Record 33 of Set 12 | marzuq
# Processing Record 34 of Set 12 | canutama
# Processing Record 35 of Set 12 | galle
# Processing Record 36 of Set 12 | rolla
# Processing Record 37 of Set 12 | martapura
# Processing Record 38 of Set 12 | luderitz
# Processing Record 39 of Set 12 | neiafu
# Processing Record 40 of Set 12 | purpe
# Processing Record 41 of Set 12 | tukrah
# Processing Record 42 of Set 12 | ouegoa
# Processing Record 43 of Set 12 | saint anthony
# Processing Record 44 of Set 12 | kyaikto
# Processing Record 45 of Set 12 | kirksville
# Processing Record 46 of Set 12 | umm kaddadah
# Processing Record 47 of Set 12 | iberia
# Processing Record 48 of Set 12 | baykit
# Processing Record 49 of Set 12 | bachaquero
# Processing Record 50 of Set 12 | caconda
# Processing Record 1 of Set 13 | stawell
# Processing Record 2 of Set 13 | kommunisticheskiy
# Processing Record 3 of Set 13 | talaya
# Processing Record 4 of Set 13 | wadi musa
# Processing Record 5 of Set 13 | parabel
# Processing Record 6 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 13 | puerto madryn
# Processing Record 8 of Set 13 | aberdeen
# Processing Record 9 of Set 13 | itarema
# Processing Record 10 of Set 13 | okhotsk
# Processing Record 11 of Set 13 | aromashevo
# Processing Record 12 of Set 13 | baruun-urt
# Processing Record 13 of Set 13 | boma
# Processing Record 14 of Set 13 | el paraiso
# Processing Record 15 of Set 13 | chuy
# Processing Record 16 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | ekibastuz
# Processing Record 18 of Set 13 | yanam
# Processing Record 19 of Set 13 | nicoya
# Processing Record 20 of Set 13 | mizdah
# Processing Record 21 of Set 13 | omsukchan
# Processing Record 22 of Set 13 | snezhnogorsk
# Processing Record 23 of Set 13 | zubtsov
# Processing Record 24 of Set 13 | dandong
# Processing Record 25 of Set 13 | shache
# Processing Record 26 of Set 13 | donskoye
# Processing Record 27 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 28 of Set 13 | borujan
# City not found. Skipping...
# Processing Record 29 of Set 13 | christchurch
# Processing Record 30 of Set 13 | poya
# Processing Record 31 of Set 13 | camana
# Processing Record 32 of Set 13 | pareora
# Processing Record 33 of Set 13 | akranes
# Processing Record 34 of Set 13 | gazli
# Processing Record 35 of Set 13 | brigantine
# Processing Record 36 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 37 of Set 13 | teguise
# Processing Record 38 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 13 | vestmannaeyjar
# Processing Record 40 of Set 13 | kokkola
# Processing Record 41 of Set 13 | soria
# Processing Record 42 of Set 13 | birjand
# Processing Record 43 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 13 | roncesvalles
# Processing Record 45 of Set 13 | ancud
# Processing Record 46 of Set 13 | panguna
# Processing Record 47 of Set 13 | san cristobal
# Processing Record 48 of Set 13 | smoky lake
# Processing Record 49 of Set 13 | saint-georges
# Processing Record 50 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 14 | atlantic city
# Processing Record 2 of Set 14 | hailey
# Processing Record 3 of Set 14 | omboue
# Processing Record 4 of Set 14 | yarada
# Processing Record 5 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 14 | san rafael
# Processing Record 7 of Set 14 | nurota
# Processing Record 8 of Set 14 | xiongshi
# City not found. Skipping...
# Processing Record 9 of Set 14 | xuanhua
# Processing Record 10 of Set 14 | yeppoon
# Processing Record 11 of Set 14 | taltal
# Processing Record 12 of Set 14 | amposta
# Processing Record 13 of Set 14 | beipiao
# Processing Record 14 of Set 14 | zhoucheng
# Processing Record 15 of Set 14 | tautira
# Processing Record 16 of Set 14 | edd
# Processing Record 17 of Set 14 | port lincoln
# Processing Record 18 of Set 14 | volga
# Processing Record 19 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 14 | hambantota
# Processing Record 21 of Set 14 | culipapa
# City not found. Skipping...
# Processing Record 22 of Set 14 | madang
# Processing Record 23 of Set 14 | igarka
# Processing Record 24 of Set 14 | dicabisagan
# Processing Record 25 of Set 14 | winsum
# Processing Record 26 of Set 14 | bud
# Processing Record 27 of Set 14 | belyy yar
# Processing Record 28 of Set 14 | ayabaca
# Processing Record 29 of Set 14 | waddan
# Processing Record 30 of Set 14 | xining
# Processing Record 31 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 14 | andilamena
# Processing Record 33 of Set 14 | minnedosa
# Processing Record 34 of Set 14 | dawson creek
# Processing Record 35 of Set 14 | magadan
# Processing Record 36 of Set 14 | mooi river
# City not found. Skipping...
# Processing Record 37 of Set 14 | sirnak
# Processing Record 38 of Set 14 | sebinkarahisar
# Processing Record 39 of Set 14 | madera
# Processing Record 40 of Set 14 | shubarshi
# Processing Record 41 of Set 14 | la ciotat
# Processing Record 42 of Set 14 | bonthe
# Processing Record 43 of Set 14 | marawi
# Processing Record 44 of Set 14 | umuarama
# Processing Record 45 of Set 14 | santiago del estero
# Processing Record 46 of Set 14 | masuguru
# Processing Record 47 of Set 14 | sao gabriel da cachoeira
# Processing Record 48 of Set 14 | umm lajj
# Processing Record 49 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 50 of Set 14 | gilbues
# Processing Record 1 of Set 15 | mehamn
# Processing Record 2 of Set 15 | luohe
# Processing Record 3 of Set 15 | svetlaya
# Processing Record 4 of Set 15 | tanshui
# City not found. Skipping...
# Processing Record 5 of Set 15 | matagami
# Processing Record 6 of Set 15 | axim
# Processing Record 7 of Set 15 | moindou
# Processing Record 8 of Set 15 | boshnyakovo
# Processing Record 9 of Set 15 | ondjiva
# Processing Record 10 of Set 15 | atar
# Processing Record 11 of Set 15 | coihueco
# Processing Record 12 of Set 15 | skjervoy
# Processing Record 13 of Set 15 | tahta
# Processing Record 14 of Set 15 | mnogovershinnyy
# Processing Record 15 of Set 15 | balkhash
# Processing Record 16 of Set 15 | baie-comeau
# Processing Record 17 of Set 15 | cabedelo
# Processing Record 18 of Set 15 | orlik
# Processing Record 19 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 15 | broken hill
# Processing Record 21 of Set 15 | abnub
# Processing Record 22 of Set 15 | hervey bay
# Processing Record 23 of Set 15 | doha
# Processing Record 24 of Set 15 | krasnyy luch
# Processing Record 25 of Set 15 | chimbote
# Processing Record 26 of Set 15 | saltpond
# Processing Record 27 of Set 15 | gijon
# Processing Record 28 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 15 | araioses
# Processing Record 30 of Set 15 | birao
# Processing Record 31 of Set 15 | bay roberts
# Processing Record 32 of Set 15 | pitimbu
# Processing Record 33 of Set 15 | santa helena de goias
# Processing Record 34 of Set 15 | darya khan mari
# City not found. Skipping...
# Processing Record 35 of Set 15 | batesville
# Processing Record 36 of Set 15 | clarence town
# Processing Record 37 of Set 15 | bekeshevskaya
# Processing Record 38 of Set 15 | dubbo
# Processing Record 39 of Set 15 | talara
# Processing Record 40 of Set 15 | cap malheureux
# Processing Record 41 of Set 15 | smidovich
# Processing Record 42 of Set 15 | pangnirtung
# Processing Record 43 of Set 15 | zhaotong
# Processing Record 44 of Set 15 | mao
# Processing Record 45 of Set 15 | sorland
# Processing Record 46 of Set 15 | nabire
# Processing Record 47 of Set 15 | kangaatsiaq
# Processing Record 48 of Set 15 | linxia
# Processing Record 49 of Set 15 | ndende
# Processing Record 50 of Set 15 | kargasok
# Processing Record 1 of Set 16 | antofagasta
# Processing Record 2 of Set 16 | makakilo city
# Processing Record 3 of Set 16 | balsas
# Processing Record 4 of Set 16 | anahuac
# Processing Record 5 of Set 16 | mitsamiouli
# Processing Record 6 of Set 16 | weihai
# Processing Record 7 of Set 16 | tumut
# Processing Record 8 of Set 16 | villamontes
# Processing Record 9 of Set 16 | najran
# Processing Record 10 of Set 16 | kantunilkin
# Processing Record 11 of Set 16 | fare
# Processing Record 12 of Set 16 | nouadhibou
# Processing Record 13 of Set 16 | mitchelstown
# Processing Record 14 of Set 16 | howard springs
# Processing Record 15 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 16 | tambo grande
# Processing Record 17 of Set 16 | alofi
# Processing Record 18 of Set 16 | upata
# Processing Record 19 of Set 16 | ternate
# Processing Record 20 of Set 16 | ust-kuyga
# Processing Record 21 of Set 16 | quebec
# Processing Record 22 of Set 16 | manggar
# Processing Record 23 of Set 16 | traverse city
# Processing Record 24 of Set 16 | fengzhen
# Processing Record 25 of Set 16 | aljezur
# Processing Record 26 of Set 16 | havelock
# Processing Record 27 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 16 | sindand
# City not found. Skipping...
# Processing Record 29 of Set 16 | sao joao da barra
# Processing Record 30 of Set 16 | camocim
# Processing Record 31 of Set 16 | pozo colorado
# Processing Record 32 of Set 16 | petatlan
# Processing Record 33 of Set 16 | paragominas
# Processing Record 34 of Set 16 | yulara
# Processing Record 35 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 16 | campobasso
# Processing Record 37 of Set 16 | erzin
# Processing Record 38 of Set 16 | ketchikan
# Processing Record 39 of Set 16 | beyneu
# Processing Record 40 of Set 16 | rafsanjan
# Processing Record 41 of Set 16 | gagarin
# Processing Record 42 of Set 16 | waipawa
# Processing Record 43 of Set 16 | mandera
# Processing Record 44 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 16 | villaviciosa
# Processing Record 46 of Set 16 | buin
# Processing Record 47 of Set 16 | phangnga
# Processing Record 48 of Set 16 | condado
# Processing Record 49 of Set 16 | dingle
# Processing Record 50 of Set 16 | aranos
# Processing Record 1 of Set 17 | ada
# Processing Record 2 of Set 17 | kopayhorod
# Processing Record 3 of Set 17 | jumla
# Processing Record 4 of Set 17 | bernalda
# Processing Record 5 of Set 17 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 17 | lazaro cardenas
# Processing Record 7 of Set 17 | kailua
# Processing Record 8 of Set 17 | grand-lahou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 744

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Padang      ID  -0.9492  100.3543     77.05        85         100
# 1       Castro      BR -24.7911  -50.0119     64.04        85          99
# 2   Carutapera      BR  -1.1950  -46.0200     77.07        91         100
# 3    Jamestown      US  42.0970  -79.2353     39.72        82           5
# 4  Yellowknife      CA  62.4560 -114.3525     28.42       100          90
# 5       Faanui      PF -16.4833 -151.7500     79.07        75          26
# 6     Yinchuan      CN  38.4681  106.2731     29.46        64         100
# 7     Lorengau      PG  -2.0226  147.2712     85.68        67          84
# 8      Chicama      PE  -7.8447  -79.1469     66.11        82          66
# 9        Taman      RU  45.2117   36.7161     46.72        83          45
#
#    Wind Speed Current Description
# 0        3.76     overcast clouds
# 1        0.78     overcast clouds
# 2        5.66     overcast clouds
# 3        1.01           clear sky
# 4       10.36     overcast clouds
# 5        7.85          light rain
# 6        7.56                snow
# 7        8.21       broken clouds
# 8        6.53       broken clouds
# 9        6.24    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
