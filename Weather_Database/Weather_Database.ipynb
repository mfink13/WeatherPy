# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Current Description": city_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | broome
# Processing Record 4 of Set 1 | senanga
# Processing Record 5 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | constitucion
# Processing Record 11 of Set 1 | kaeo
# Processing Record 12 of Set 1 | toftlund
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | meulaboh
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | tuatapere
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | abu kamal
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | menongue
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | ilula
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | port-cartier
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 1 | khuzhir
# Processing Record 33 of Set 1 | floresti
# Processing Record 34 of Set 1 | hervey bay
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | kushiro
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | vestmannaeyjar
# Processing Record 46 of Set 1 | santa marta
# Processing Record 47 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | arys
# Processing Record 1 of Set 2 | yar-sale
# Processing Record 2 of Set 2 | sur
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | gayeri
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | ceuta
# Processing Record 8 of Set 2 | francistown
# Processing Record 9 of Set 2 | yeppoon
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | inhambane
# Processing Record 12 of Set 2 | kahului
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | naze
# Processing Record 15 of Set 2 | chumikan
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | hasaki
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | komsomolskiy
# Processing Record 22 of Set 2 | maningrida
# Processing Record 23 of Set 2 | villazon
# Processing Record 24 of Set 2 | sursk
# Processing Record 25 of Set 2 | verkhoyansk
# Processing Record 26 of Set 2 | westport
# Processing Record 27 of Set 2 | mayo
# Processing Record 28 of Set 2 | azrow
# City not found. Skipping...
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | los llanos de aridane
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | yerbogachen
# Processing Record 36 of Set 2 | lorengau
# Processing Record 37 of Set 2 | gorontalo
# Processing Record 38 of Set 2 | conceicao da barra
# Processing Record 39 of Set 2 | macapa
# Processing Record 40 of Set 2 | sivas
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | cavnic
# Processing Record 44 of Set 2 | bowen
# Processing Record 45 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | malpe
# Processing Record 48 of Set 2 | vangaindrano
# Processing Record 49 of Set 2 | krasnoselkup
# Processing Record 50 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | mehamn
# Processing Record 3 of Set 3 | galle
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | soloneshnoye
# Processing Record 8 of Set 3 | esperance
# Processing Record 9 of Set 3 | japura
# Processing Record 10 of Set 3 | namibe
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | geraldton
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | marrakesh
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | vysokogornyy
# Processing Record 19 of Set 3 | goundam
# Processing Record 20 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 3 | benoy
# Processing Record 22 of Set 3 | matay
# Processing Record 23 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 3 | dudinka
# Processing Record 25 of Set 3 | bereda
# Processing Record 26 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | ribeira grande
# Processing Record 29 of Set 3 | chifeng
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | mangrol
# Processing Record 36 of Set 3 | dasoguz
# Processing Record 37 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 3 | tecoanapa
# Processing Record 39 of Set 3 | acajutla
# Processing Record 40 of Set 3 | ciras
# City not found. Skipping...
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | birjand
# Processing Record 44 of Set 3 | hambantota
# Processing Record 45 of Set 3 | the valley
# Processing Record 46 of Set 3 | bethel
# Processing Record 47 of Set 3 | estelle
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | wucheng
# Processing Record 50 of Set 3 | shasta lake
# Processing Record 1 of Set 4 | gimbi
# Processing Record 2 of Set 4 | kiruna
# Processing Record 3 of Set 4 | nishihara
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | melita
# Processing Record 6 of Set 4 | deputatskiy
# Processing Record 7 of Set 4 | kuching
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 4 | turrialba
# Processing Record 12 of Set 4 | naryan-mar
# Processing Record 13 of Set 4 | zapolyarnyy
# Processing Record 14 of Set 4 | dustlik
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | bonthe
# Processing Record 17 of Set 4 | ahipara
# Processing Record 18 of Set 4 | talaya
# Processing Record 19 of Set 4 | neuquen
# Processing Record 20 of Set 4 | satipo
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | bengkulu
# Processing Record 23 of Set 4 | hofn
# Processing Record 24 of Set 4 | bonfim
# Processing Record 25 of Set 4 | owerri
# Processing Record 26 of Set 4 | manokwari
# Processing Record 27 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | alausi
# Processing Record 31 of Set 4 | bubaque
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | port hedland
# Processing Record 34 of Set 4 | salalah
# Processing Record 35 of Set 4 | jimma
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | moron
# Processing Record 39 of Set 4 | bali
# Processing Record 40 of Set 4 | klaksvik
# Processing Record 41 of Set 4 | new norfolk
# Processing Record 42 of Set 4 | cabatuan
# Processing Record 43 of Set 4 | baymak
# Processing Record 44 of Set 4 | netanya
# Processing Record 45 of Set 4 | kingisepp
# Processing Record 46 of Set 4 | dunedin
# Processing Record 47 of Set 4 | karaton
# Processing Record 48 of Set 4 | kazachinskoye
# Processing Record 49 of Set 4 | porto velho
# Processing Record 50 of Set 4 | shimoda
# Processing Record 1 of Set 5 | port blair
# Processing Record 2 of Set 5 | upington
# Processing Record 3 of Set 5 | amuntai
# Processing Record 4 of Set 5 | gusinoye ozero
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | monticello
# Processing Record 7 of Set 5 | ust-koksa
# Processing Record 8 of Set 5 | sosnovo-ozerskoye
# Processing Record 9 of Set 5 | berlevag
# Processing Record 10 of Set 5 | yaan
# Processing Record 11 of Set 5 | kurchum
# Processing Record 12 of Set 5 | cermik
# Processing Record 13 of Set 5 | ambilobe
# Processing Record 14 of Set 5 | portland
# Processing Record 15 of Set 5 | kaitangata
# Processing Record 16 of Set 5 | cayenne
# Processing Record 17 of Set 5 | saint-augustin
# Processing Record 18 of Set 5 | huarmey
# Processing Record 19 of Set 5 | presidente medici
# Processing Record 20 of Set 5 | yellowknife
# Processing Record 21 of Set 5 | quatre cocos
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | caldas novas
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | saint anthony
# Processing Record 27 of Set 5 | bokoro
# Processing Record 28 of Set 5 | chinacota
# Processing Record 29 of Set 5 | charters towers
# Processing Record 30 of Set 5 | aksarka
# Processing Record 31 of Set 5 | nueva concepcion
# Processing Record 32 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 33 of Set 5 | tomatlan
# Processing Record 34 of Set 5 | tuktoyaktuk
# Processing Record 35 of Set 5 | san quintin
# Processing Record 36 of Set 5 | stornoway
# Processing Record 37 of Set 5 | sao filipe
# Processing Record 38 of Set 5 | katha
# City not found. Skipping...
# Processing Record 39 of Set 5 | itaberaba
# Processing Record 40 of Set 5 | vao
# Processing Record 41 of Set 5 | morales
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | aklavik
# Processing Record 44 of Set 5 | samoylovka
# Processing Record 45 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 5 | flin flon
# Processing Record 47 of Set 5 | gilbues
# Processing Record 48 of Set 5 | coxim
# Processing Record 49 of Set 5 | tilik
# Processing Record 50 of Set 5 | saint george
# Processing Record 1 of Set 6 | rovaniemi
# Processing Record 2 of Set 6 | ono
# Processing Record 3 of Set 6 | kenai
# Processing Record 4 of Set 6 | nipawin
# Processing Record 5 of Set 6 | yumen
# Processing Record 6 of Set 6 | opuwo
# Processing Record 7 of Set 6 | eyl
# Processing Record 8 of Set 6 | jaciara
# Processing Record 9 of Set 6 | mutsu
# Processing Record 10 of Set 6 | channel-port aux basques
# Processing Record 11 of Set 6 | nicoya
# Processing Record 12 of Set 6 | alta floresta
# Processing Record 13 of Set 6 | albeni
# Processing Record 14 of Set 6 | soe
# Processing Record 15 of Set 6 | acarau
# Processing Record 16 of Set 6 | hami
# Processing Record 17 of Set 6 | artyom
# Processing Record 18 of Set 6 | paranhos
# Processing Record 19 of Set 6 | batagay
# Processing Record 20 of Set 6 | whitehorse
# Processing Record 21 of Set 6 | ponta delgada
# Processing Record 22 of Set 6 | kavieng
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | filadelfia
# Processing Record 25 of Set 6 | chirongui
# Processing Record 26 of Set 6 | saint-pierre
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | contamana
# Processing Record 30 of Set 6 | sobolevo
# Processing Record 31 of Set 6 | le moule
# Processing Record 32 of Set 6 | port antonio
# Processing Record 33 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 34 of Set 6 | kilmez
# City not found. Skipping...
# Processing Record 35 of Set 6 | ibipeba
# Processing Record 36 of Set 6 | serenje
# Processing Record 37 of Set 6 | roebourne
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | bela
# Processing Record 40 of Set 6 | otane
# Processing Record 41 of Set 6 | yarmouth
# Processing Record 42 of Set 6 | cordoba
# Processing Record 43 of Set 6 | lalmohan
# Processing Record 44 of Set 6 | muzaffarabad
# Processing Record 45 of Set 6 | okitipupa
# Processing Record 46 of Set 6 | burns lake
# Processing Record 47 of Set 6 | biloela
# Processing Record 48 of Set 6 | trogir
# Processing Record 49 of Set 6 | abrau-dyurso
# Processing Record 50 of Set 6 | adre
# Processing Record 1 of Set 7 | valparaiso
# Processing Record 2 of Set 7 | bara
# Processing Record 3 of Set 7 | banda aceh
# Processing Record 4 of Set 7 | bundaberg
# Processing Record 5 of Set 7 | waipawa
# Processing Record 6 of Set 7 | dehloran
# Processing Record 7 of Set 7 | bontang
# Processing Record 8 of Set 7 | alice springs
# Processing Record 9 of Set 7 | labuhan
# Processing Record 10 of Set 7 | sao jose da coroa grande
# Processing Record 11 of Set 7 | guerrero negro
# Processing Record 12 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 7 | lircay
# Processing Record 14 of Set 7 | asau
# Processing Record 15 of Set 7 | bone
# Processing Record 16 of Set 7 | college
# Processing Record 17 of Set 7 | san clemente
# Processing Record 18 of Set 7 | pacific grove
# Processing Record 19 of Set 7 | hudson bay
# Processing Record 20 of Set 7 | arlit
# Processing Record 21 of Set 7 | zyryanka
# Processing Record 22 of Set 7 | betioky
# Processing Record 23 of Set 7 | ouallam
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | port-gentil
# Processing Record 26 of Set 7 | plettenberg bay
# Processing Record 27 of Set 7 | icatu
# Processing Record 28 of Set 7 | smolenka
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | arnstadt
# Processing Record 31 of Set 7 | mayor pablo lagerenza
# Processing Record 32 of Set 7 | tubuala
# Processing Record 33 of Set 7 | baykit
# Processing Record 34 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 7 | kovdor
# Processing Record 36 of Set 7 | turbat
# Processing Record 37 of Set 7 | amapa
# Processing Record 38 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 7 | krasnogvardeyets
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | pietarsaari
# Processing Record 42 of Set 7 | umm kaddadah
# Processing Record 43 of Set 7 | mweka
# Processing Record 44 of Set 7 | itarema
# Processing Record 45 of Set 7 | imisli
# City not found. Skipping...
# Processing Record 46 of Set 7 | khatanga
# Processing Record 47 of Set 7 | kismayo
# Processing Record 48 of Set 7 | karcag
# Processing Record 49 of Set 7 | havelock
# Processing Record 50 of Set 7 | sabha
# Processing Record 1 of Set 8 | bucerias
# Processing Record 2 of Set 8 | semey
# Processing Record 3 of Set 8 | bilma
# Processing Record 4 of Set 8 | barinas
# Processing Record 5 of Set 8 | collie
# Processing Record 6 of Set 8 | qaqortoq
# Processing Record 7 of Set 8 | mafinga
# Processing Record 8 of Set 8 | grand gaube
# Processing Record 9 of Set 8 | la ronge
# Processing Record 10 of Set 8 | faanui
# Processing Record 11 of Set 8 | sydney
# Processing Record 12 of Set 8 | koratagere
# Processing Record 13 of Set 8 | souillac
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | hanna
# Processing Record 16 of Set 8 | dongobesh
# Processing Record 17 of Set 8 | codrington
# Processing Record 18 of Set 8 | rio grande
# Processing Record 19 of Set 8 | tabuk
# Processing Record 20 of Set 8 | bo phloi
# Processing Record 21 of Set 8 | ekibastuz
# Processing Record 22 of Set 8 | keti bandar
# Processing Record 23 of Set 8 | wajima
# Processing Record 24 of Set 8 | bathsheba
# Processing Record 25 of Set 8 | adrar
# Processing Record 26 of Set 8 | ingham
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | key west
# Processing Record 29 of Set 8 | maracaibo
# Processing Record 30 of Set 8 | flinders
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | dhidhdhoo
# Processing Record 33 of Set 8 | aiyina
# City not found. Skipping...
# Processing Record 34 of Set 8 | chatsu
# City not found. Skipping...
# Processing Record 35 of Set 8 | solwezi
# Processing Record 36 of Set 8 | merauke
# Processing Record 37 of Set 8 | umm lajj
# Processing Record 38 of Set 8 | pizarro
# Processing Record 39 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 8 | anadyr
# Processing Record 42 of Set 8 | yushu
# Processing Record 43 of Set 8 | sao felix do xingu
# Processing Record 44 of Set 8 | lensk
# Processing Record 45 of Set 8 | dovers
# Processing Record 46 of Set 8 | fort nelson
# Processing Record 47 of Set 8 | tabas
# Processing Record 48 of Set 8 | malakal
# Processing Record 49 of Set 8 | semnan
# Processing Record 50 of Set 8 | sayyan
# Processing Record 1 of Set 9 | puerto escondido
# Processing Record 2 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 3 of Set 9 | alofi
# Processing Record 4 of Set 9 | clyde river
# Processing Record 5 of Set 9 | gravdal
# Processing Record 6 of Set 9 | yulara
# Processing Record 7 of Set 9 | san rafael
# Processing Record 8 of Set 9 | sangar
# Processing Record 9 of Set 9 | steamboat springs
# Processing Record 10 of Set 9 | atambua
# Processing Record 11 of Set 9 | akyab
# Processing Record 12 of Set 9 | mackay
# Processing Record 13 of Set 9 | penhold
# Processing Record 14 of Set 9 | kaputa
# Processing Record 15 of Set 9 | vanimo
# Processing Record 16 of Set 9 | trelew
# Processing Record 17 of Set 9 | biskamzha
# Processing Record 18 of Set 9 | koroni
# Processing Record 19 of Set 9 | muisne
# Processing Record 20 of Set 9 | fairfield
# Processing Record 21 of Set 9 | gamboula
# Processing Record 22 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 23 of Set 9 | arman
# Processing Record 24 of Set 9 | xingyi
# Processing Record 25 of Set 9 | huilong
# Processing Record 26 of Set 9 | henties bay
# Processing Record 27 of Set 9 | okhotsk
# Processing Record 28 of Set 9 | amahai
# Processing Record 29 of Set 9 | sandnessjoen
# Processing Record 30 of Set 9 | hailun
# Processing Record 31 of Set 9 | russell
# Processing Record 32 of Set 9 | chingirlau
# Processing Record 33 of Set 9 | srednekolymsk
# Processing Record 34 of Set 9 | kavaratti
# Processing Record 35 of Set 9 | tura
# Processing Record 36 of Set 9 | marawi
# Processing Record 37 of Set 9 | suluq
# Processing Record 38 of Set 9 | pimenta bueno
# Processing Record 39 of Set 9 | awjilah
# Processing Record 40 of Set 9 | ryotsu
# Processing Record 41 of Set 9 | celina
# Processing Record 42 of Set 9 | maimon
# City not found. Skipping...
# Processing Record 43 of Set 9 | norman wells
# Processing Record 44 of Set 9 | margate
# Processing Record 45 of Set 9 | kutum
# Processing Record 46 of Set 9 | daugavpils
# Processing Record 47 of Set 9 | palmer
# Processing Record 48 of Set 9 | kitimat
# Processing Record 49 of Set 9 | banepa
# Processing Record 50 of Set 9 | sao joao da barra
# Processing Record 1 of Set 10 | ullapool
# Processing Record 2 of Set 10 | riyadh
# Processing Record 3 of Set 10 | asyut
# Processing Record 4 of Set 10 | goba
# Processing Record 5 of Set 10 | mahebourg
# Processing Record 6 of Set 10 | logrono
# Processing Record 7 of Set 10 | bartica
# Processing Record 8 of Set 10 | damghan
# Processing Record 9 of Set 10 | bud
# Processing Record 10 of Set 10 | ambon
# Processing Record 11 of Set 10 | airai
# Processing Record 12 of Set 10 | sola
# Processing Record 13 of Set 10 | camacha
# Processing Record 14 of Set 10 | san gabriel casa blanca
# Processing Record 15 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 10 | san cristobal
# Processing Record 18 of Set 10 | north bend
# Processing Record 19 of Set 10 | makakilo city
# Processing Record 20 of Set 10 | popondetta
# Processing Record 21 of Set 10 | santa maria
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | liverpool
# Processing Record 24 of Set 10 | victoria
# Processing Record 25 of Set 10 | half moon bay
# Processing Record 26 of Set 10 | gora
# Processing Record 27 of Set 10 | colares
# Processing Record 28 of Set 10 | baghdad
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | brigantine
# Processing Record 31 of Set 10 | gribanovskiy
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | jumla
# Processing Record 34 of Set 10 | maceio
# Processing Record 35 of Set 10 | manicore
# Processing Record 36 of Set 10 | kukshi
# Processing Record 37 of Set 10 | ashtabula
# Processing Record 38 of Set 10 | bhinmal
# Processing Record 39 of Set 10 | shirokiy
# Processing Record 40 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 41 of Set 10 | nouakchott
# Processing Record 42 of Set 10 | namatanai
# Processing Record 43 of Set 10 | port hardy
# Processing Record 44 of Set 10 | hopkinsville
# Processing Record 45 of Set 10 | shenzhen
# Processing Record 46 of Set 10 | pastavy
# Processing Record 47 of Set 10 | mount gambier
# Processing Record 48 of Set 10 | ouadda
# Processing Record 49 of Set 10 | weyburn
# Processing Record 50 of Set 10 | beringovskiy
# Processing Record 1 of Set 11 | ivanteyevka
# Processing Record 2 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 11 | porto novo
# Processing Record 4 of Set 11 | conde
# Processing Record 5 of Set 11 | gamba
# Processing Record 6 of Set 11 | vari
# Processing Record 7 of Set 11 | svetlaya
# Processing Record 8 of Set 11 | svetlogorsk
# Processing Record 9 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 11 | dombarovskiy
# Processing Record 11 of Set 11 | santa isabel do rio negro
# Processing Record 12 of Set 11 | auki
# Processing Record 13 of Set 11 | lahij
# Processing Record 14 of Set 11 | boa vista
# Processing Record 15 of Set 11 | bac lieu
# Processing Record 16 of Set 11 | mantua
# Processing Record 17 of Set 11 | sumbe
# Processing Record 18 of Set 11 | vestmanna
# Processing Record 19 of Set 11 | kozhva
# Processing Record 20 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 21 of Set 11 | strezhevoy
# Processing Record 22 of Set 11 | almeirim
# Processing Record 23 of Set 11 | ulladulla
# Processing Record 24 of Set 11 | sinnamary
# Processing Record 25 of Set 11 | rodrigues alves
# Processing Record 26 of Set 11 | dicabisagan
# Processing Record 27 of Set 11 | bobo dioulasso
# Processing Record 28 of Set 11 | pingzhuang
# Processing Record 29 of Set 11 | coahuayana
# Processing Record 30 of Set 11 | wagar
# Processing Record 31 of Set 11 | kudahuvadhoo
# Processing Record 32 of Set 11 | carberry
# Processing Record 33 of Set 11 | dergachi
# Processing Record 34 of Set 11 | jalu
# Processing Record 35 of Set 11 | vernon
# Processing Record 36 of Set 11 | nikolayevka
# Processing Record 37 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 11 | njombe
# Processing Record 39 of Set 11 | kautokeino
# Processing Record 40 of Set 11 | cockburn town
# Processing Record 41 of Set 11 | quang ngai
# Processing Record 42 of Set 11 | zhuanghe
# Processing Record 43 of Set 11 | bilibino
# Processing Record 44 of Set 11 | kumluca
# Processing Record 45 of Set 11 | gizo
# Processing Record 46 of Set 11 | nabire
# Processing Record 47 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 11 | kachug
# Processing Record 49 of Set 11 | muzhi
# Processing Record 50 of Set 11 | poum
# Processing Record 1 of Set 12 | jenbach
# Processing Record 2 of Set 12 | aguas formosas
# Processing Record 3 of Set 12 | inirida
# Processing Record 4 of Set 12 | capaccio
# Processing Record 5 of Set 12 | bourail
# Processing Record 6 of Set 12 | skhisma
# Processing Record 7 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 8 of Set 12 | morris
# Processing Record 9 of Set 12 | ballina
# Processing Record 10 of Set 12 | buin
# Processing Record 11 of Set 12 | anuradhapura
# Processing Record 12 of Set 12 | buraydah
# Processing Record 13 of Set 12 | goderich
# Processing Record 14 of Set 12 | tambura
# Processing Record 15 of Set 12 | marsh harbour
# Processing Record 16 of Set 12 | yafran
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | bealanana
# Processing Record 19 of Set 12 | salto del guaira
# Processing Record 20 of Set 12 | san luis
# Processing Record 21 of Set 12 | saint-joseph
# Processing Record 22 of Set 12 | sergeyevka
# Processing Record 23 of Set 12 | taoudenni
# Processing Record 24 of Set 12 | olafsvik
# Processing Record 25 of Set 12 | bulri
# Processing Record 26 of Set 12 | sisimiut
# Processing Record 27 of Set 12 | zhigansk
# Processing Record 28 of Set 12 | metro
# Processing Record 29 of Set 12 | plainview
# Processing Record 30 of Set 12 | teguldet
# Processing Record 31 of Set 12 | sesimbra
# Processing Record 32 of Set 12 | ayan
# Processing Record 33 of Set 12 | kemijarvi
# Processing Record 34 of Set 12 | omboue
# Processing Record 35 of Set 12 | umba
# Processing Record 36 of Set 12 | tucuma
# Processing Record 37 of Set 12 | ystad
# Processing Record 38 of Set 12 | severo-kurilsk
# Processing Record 39 of Set 12 | sorong
# Processing Record 40 of Set 12 | kirakira
# Processing Record 41 of Set 12 | puerto del rosario
# Processing Record 42 of Set 12 | mwinilunga
# Processing Record 43 of Set 12 | mayenne
# Processing Record 44 of Set 12 | wanxian
# Processing Record 45 of Set 12 | chilliwack
# Processing Record 46 of Set 12 | cascais
# Processing Record 47 of Set 12 | lima
# Processing Record 48 of Set 12 | ixtapa
# Processing Record 49 of Set 12 | lusambo
# Processing Record 50 of Set 12 | severo-yeniseyskiy
# Processing Record 1 of Set 13 | brignoles
# Processing Record 2 of Set 13 | ancud
# Processing Record 3 of Set 13 | aykhal
# Processing Record 4 of Set 13 | derzhavinsk
# Processing Record 5 of Set 13 | ust-barguzin
# Processing Record 6 of Set 13 | port keats
# Processing Record 7 of Set 13 | saint-francois
# Processing Record 8 of Set 13 | dhandhuka
# Processing Record 9 of Set 13 | wewak
# Processing Record 10 of Set 13 | portree
# Processing Record 11 of Set 13 | mumbwa
# Processing Record 12 of Set 13 | comarapa
# Processing Record 13 of Set 13 | gisborne
# Processing Record 14 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 13 | durham
# Processing Record 16 of Set 13 | paamiut
# Processing Record 17 of Set 13 | normandin
# Processing Record 18 of Set 13 | antofagasta
# Processing Record 19 of Set 13 | kanel
# Processing Record 20 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 13 | el alto
# Processing Record 22 of Set 13 | vieste
# Processing Record 23 of Set 13 | pundaguitan
# Processing Record 24 of Set 13 | xuddur
# Processing Record 25 of Set 13 | nesterov
# Processing Record 26 of Set 13 | buala
# Processing Record 27 of Set 13 | krasnaya polyana
# Processing Record 28 of Set 13 | kaohsiung
# Processing Record 29 of Set 13 | durango
# Processing Record 30 of Set 13 | ternate
# Processing Record 31 of Set 13 | iquique
# Processing Record 32 of Set 13 | sovetskiy
# Processing Record 33 of Set 13 | nemuro
# Processing Record 34 of Set 13 | takoradi
# Processing Record 35 of Set 13 | baringo
# Processing Record 36 of Set 13 | antakya
# Processing Record 37 of Set 13 | cuamba
# Processing Record 38 of Set 13 | khor
# Processing Record 39 of Set 13 | najran
# Processing Record 40 of Set 13 | jardim
# Processing Record 41 of Set 13 | zaraza
# Processing Record 42 of Set 13 | terrace bay
# Processing Record 43 of Set 13 | papara
# Processing Record 44 of Set 13 | navabad
# City not found. Skipping...
# Processing Record 45 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 13 | ola
# Processing Record 47 of Set 13 | macau
# Processing Record 48 of Set 13 | ostersund
# Processing Record 49 of Set 13 | kieta
# Processing Record 50 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 14 | gubkinskiy
# Processing Record 2 of Set 14 | lazaro cardenas
# Processing Record 3 of Set 14 | nurobod
# Processing Record 4 of Set 14 | otukpo
# Processing Record 5 of Set 14 | ray
# Processing Record 6 of Set 14 | tigre
# Processing Record 7 of Set 14 | solikamsk
# Processing Record 8 of Set 14 | vardo
# Processing Record 9 of Set 14 | sesheke
# Processing Record 10 of Set 14 | albania
# Processing Record 11 of Set 14 | avera
# Processing Record 12 of Set 14 | samarai
# Processing Record 13 of Set 14 | zaysan
# Processing Record 14 of Set 14 | puli
# Processing Record 15 of Set 14 | great yarmouth
# Processing Record 16 of Set 14 | abalak
# Processing Record 17 of Set 14 | karasjok
# Processing Record 18 of Set 14 | saint-georges
# Processing Record 19 of Set 14 | havre-saint-pierre
# Processing Record 20 of Set 14 | pilot butte
# Processing Record 21 of Set 14 | brae
# Processing Record 22 of Set 14 | baruun-urt
# Processing Record 23 of Set 14 | pinawa
# Processing Record 24 of Set 14 | mogadishu
# Processing Record 25 of Set 14 | windhoek
# Processing Record 26 of Set 14 | johnshaven
# Processing Record 27 of Set 14 | manzhouli
# Processing Record 28 of Set 14 | lora del rio
# Processing Record 29 of Set 14 | beihai
# Processing Record 30 of Set 14 | chernyshevskiy
# Processing Record 31 of Set 14 | maun
# Processing Record 32 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 14 | lazarev
# Processing Record 34 of Set 14 | khasan
# Processing Record 35 of Set 14 | englehart
# Processing Record 36 of Set 14 | batu
# Processing Record 37 of Set 14 | norrtalje
# Processing Record 38 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 14 | biak
# Processing Record 40 of Set 14 | constantine
# Processing Record 41 of Set 14 | mitsamiouli
# Processing Record 42 of Set 14 | taltal
# Processing Record 43 of Set 14 | sibolga
# Processing Record 44 of Set 14 | baglung
# Processing Record 45 of Set 14 | ho
# City not found. Skipping...
# Processing Record 46 of Set 14 | hovd
# Processing Record 47 of Set 14 | umarkot
# Processing Record 48 of Set 14 | kaithal
# Processing Record 49 of Set 14 | scarborough
# Processing Record 50 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 15 | miri
# Processing Record 2 of Set 15 | batticaloa
# Processing Record 3 of Set 15 | puerto carreno
# Processing Record 4 of Set 15 | sao lourenco da serra
# Processing Record 5 of Set 15 | kendari
# Processing Record 6 of Set 15 | esso
# Processing Record 7 of Set 15 | ndele
# Processing Record 8 of Set 15 | anjozorobe
# Processing Record 9 of Set 15 | sarai naurang
# Processing Record 10 of Set 15 | camalu
# Processing Record 11 of Set 15 | aksarayskiy
# Processing Record 12 of Set 15 | flagstaff
# Processing Record 13 of Set 15 | fairbanks
# Processing Record 14 of Set 15 | nandi
# Processing Record 15 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 16 of Set 15 | champerico
# Processing Record 17 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 15 | port macquarie
# Processing Record 19 of Set 15 | wadenswil
# Processing Record 20 of Set 15 | galeana
# Processing Record 21 of Set 15 | shakawe
# Processing Record 22 of Set 15 | laizhou
# Processing Record 23 of Set 15 | katherine
# Processing Record 24 of Set 15 | pichayevo
# Processing Record 25 of Set 15 | skjervoy
# Processing Record 26 of Set 15 | requena
# Processing Record 27 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 15 | diphu
# Processing Record 29 of Set 15 | bursol
# City not found. Skipping...
# Processing Record 30 of Set 15 | vradiyivka
# Processing Record 31 of Set 15 | nizhneudinsk
# Processing Record 32 of Set 15 | waingapu
# Processing Record 33 of Set 15 | elizabeth city
# Processing Record 34 of Set 15 | trinidad
# Processing Record 35 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 36 of Set 15 | charlestown
# Processing Record 37 of Set 15 | kalga
# Processing Record 38 of Set 15 | suoyarvi
# Processing Record 39 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 15 | visby
# Processing Record 41 of Set 15 | shetpe
# Processing Record 42 of Set 15 | chazuta
# Processing Record 43 of Set 15 | namie
# Processing Record 44 of Set 15 | grindavik
# Processing Record 45 of Set 15 | kihei
# Processing Record 46 of Set 15 | heihe
# Processing Record 47 of Set 15 | wattegama
# Processing Record 48 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 49 of Set 15 | nuuk
# Processing Record 50 of Set 15 | vinh
# Processing Record 1 of Set 16 | minbu
# Processing Record 2 of Set 16 | higuey
# City not found. Skipping...
# Processing Record 3 of Set 16 | de-kastri
# Processing Record 4 of Set 16 | ucluelet
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 691

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     72.93        33         100
# 1    Longyearbyen      SJ  78.2186   15.6401      8.46        88          87
# 2          Broome      US  42.2506  -75.8330     35.55        70           8
# 3         Senanga      ZM -16.1167   23.2667     73.26        54          83
# 4        Hermanus      ZA -34.4187   19.2345     55.90        76          11
# 5         Iqaluit      CA  63.7506  -68.5145     11.93        78          40
# 6       Cape Town      ZA -33.9258   18.4232     56.12        82          40
# 7  Saint-Philippe      RE -21.3585   55.7679     73.22        73           0
# 8    Constitucion      CL -35.3333  -72.4167     50.83        89           1
# 9            Kaeo      NZ -35.1000  173.7833     63.12        90          59
#
#    Wind Speed Current Description
# 0        2.62     overcast clouds
# 1        1.86     overcast clouds
# 2        3.00           clear sky
# 3        4.29       broken clouds
# 4        5.01          few clouds
# 5        3.00    scattered clouds
# 6        3.44    scattered clouds
# 7        6.06           clear sky
# 8        2.73           clear sky
# 9        3.53       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
